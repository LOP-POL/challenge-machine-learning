# %% [markdown]
# # AutoML AutoGluon #
# Arhan Erdogan

# %% [markdown]
# #### Imports

# %%
from autogluon.tabular import TabularPredictor
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
script_dir = os.getcwd()
rel_path = "intermediate"

dataset = pd.read_csv(os.path.join(script_dir, rel_path, "CLEAN_data_injection_moulding.csv"))

# %% [markdown]
# #### Feature selection
# 2 different scenarios with and without ZUs as it dominates

# %%
# features = ['ZSx [s]', 'ACPx [cm³]', 'ZDx [s]', 'ZEx [s]', 'APHu [bar]', 'GEx [kWh]', 'GPx [kW]', 'HPx [kW]', 'HEx [kWh]', 'MPx [kW]', 'ESPx [kWh/kg]', 'H16x [°C]', 'H15x [°C]', 'H10x [°C]', 'H12x [°C]', 'H9x [°C]', 'H11x [°C]']

features = ['ZUs [s]','ZSx [s]', 'ACPx [cm³]', 'ZDx [s]', 'ZEx [s]', 'APHu [bar]', 'GEx [kWh]', 'GPx [kW]', 'HPx [kW]', 'HEx [kWh]', 'MPx [kW]', 'ESPx [kWh/kg]', 'H16x [°C]', 'H15x [°C]', 'H10x [°C]', 'H12x [°C]', 'H9x [°C]', 'H11x [°C]']

X = dataset[features]
y = dataset['ASZ [Sch]']
train_data = pd.concat([X, y], axis=1)

# %% [markdown]
# #### Train-Test split

# %%
train_df, test_df = train_test_split(train_data, test_size=0.2, random_state=42)

print(f"Training samples: {len(train_df)}")
print(f"Test samples: {len(test_df)}")
print(f"Scrap ratio in training: {train_df['ASZ [Sch]'].sum() / len(train_df):.3f}")
# Out:
# Training samples: 3883
# Test samples: 971
# Scrap ratio in training: 0.032

# %% [markdown]
# #### Training AutoGluon ####

# %%
predictor = TabularPredictor(
    label='ASZ [Sch]',
    eval_metric='f1',
    problem_type='binary',
    path='./autogluon_models'
).fit(
    train_data=train_df,
    time_limit=600,
    presets='best_quality',
    verbosity=2
)

leaderboard = predictor.leaderboard(test_df, silent=True)
print("Model leaderboard")
print(leaderboard)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.5.0
# Python Version:     3.13.3
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26200
# CPU Count:          16
# Pytorch Version:    2.9.1+cpu
# CUDA Version:       CUDA is not available
# Memory Avail:       3.12 GB / 15.41 GB (20.3%)
# Disk Space Avail:   256.30 GB / 930.63 GB (27.5%)
# ===================================================
# Presets specified: ['best_quality']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 150s of the 600s of remaining time (25%).
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\autogluon\tabular\predictor\predictor.py:1493: UserWarning: Failed to use ray for memory safe fits. Falling back to normal fit. Error: ImportError('ray is required to train folds in parallel for TabularPredictor or HPO for MultiModalPredictor. A quick tip is to install via `pip install "ray>=2.43.0,<2.53.0"`')
#   stacked_overfitting = self._sub_fit_memory_save_wrapper(
# 		Context path: "C:\Users\Sc\Documents\GitHub\challenge-machine-learning\autogluon_models\ds_sub_fit\sub_fit_ho"
# Running DyStack sub-fit ...
# Beginning AutoGluon training ... Time limit = 150s
# AutoGluon will save models to "C:\Users\Sc\Documents\GitHub\challenge-machine-learning\autogluon_models\ds_sub_fit\sub_fit_ho"
# Train Data Rows:    3451
# Train Data Columns: 18
# Label Column:       ASZ [Sch]
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    3178.05 MB
# 	Train Data (Original)  Memory Usage: 0.47 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 1): ['APHu [bar]']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 17 | ['ZUs [s]', 'ZSx [s]', 'ACPx [cm³]', 'ZDx [s]', 'ZEx [s]', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 17 | ['ZUs [s]', 'ZSx [s]', 'ACPx [cm³]', 'ZDx [s]', 'ZEx [s]', ...]
# 	0.1s = Fit runtime
# 	17 features in original data used to generate 17 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.45 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.07s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'f1'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 108 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 99.92s of the 149.91s of remaining time.
# Will use sequential fold fitting strategy because import of ray failed. Reason: ray is required to train folds in parallel for TabularPredictor or HPO for MultiModalPredictor. A quick tip is to install via `pip install "ray>=2.43.0,<2.53.0"`
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	0.9727	 = Validation score   (f1)
# 	16.65s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 81.05s of the 131.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	0.9686	 = Validation score   (f1)
# 	17.04s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 63.87s of the 113.86s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/3.2 GB
# 	0.9554	 = Validation score   (f1)
# 	1.08s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 62.63s of the 112.61s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/3.1 GB
# 	0.964	 = Validation score   (f1)
# 	0.63s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 61.82s of the 111.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	0.96	 = Validation score   (f1)
# 	18.53s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 43.16s of the 93.15s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/3.2 GB
# 	0.9604	 = Validation score   (f1)
# 	0.66s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 42.33s of the 92.31s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/3.2 GB
# 	0.96	 = Validation score   (f1)
# 	0.66s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 41.49s of the 91.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# No improvement since epoch 5: early stopping
# 	Time limit exceeded... Skipping NeuralNetFastAI_BAG_L1.
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 36.01s of the 86.00s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	0.9683	 = Validation score   (f1)
# 	9.7s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 26.13s of the 76.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	Time limit exceeded... Skipping NeuralNetTorch_BAG_L1.
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 23.89s of the 73.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	Ran out of time, early stopping on iteration 311. Best iteration is:
# 	[112]	valid_set's binary_logloss: 0.00519786	valid_set's f1: 1
# 	Ran out of time, early stopping on iteration 336. Best iteration is:
# 	[57]	valid_set's binary_logloss: 0.030926	valid_set's f1: 0.923077
# 	Ran out of time, early stopping on iteration 307. Best iteration is:
# 	[24]	valid_set's binary_logloss: 0.0359119	valid_set's f1: 1
# 	Ran out of time, early stopping on iteration 312. Best iteration is:
# 	[58]	valid_set's binary_logloss: 0.0151211	valid_set's f1: 0.96
# 	Ran out of time, early stopping on iteration 320. Best iteration is:
# 	[63]	valid_set's binary_logloss: 0.0140572	valid_set's f1: 1
# 	0.9589	 = Validation score   (f1)
# 	20.72s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 3.01s of the 53.00s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	Ran out of time, early stopping on iteration 108.
# 	Ran out of time, early stopping on iteration 109.
# 	Ran out of time, early stopping on iteration 116.
# 	Ran out of time, early stopping on iteration 121.
# 	Ran out of time, early stopping on iteration 123.
# 	Ran out of time, early stopping on iteration 126.
# 	Ran out of time, early stopping on iteration 140.
# 	Ran out of time, early stopping on iteration 163.
# 	0.9554	 = Validation score   (f1)
# 	2.81s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 0.07s of the 50.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	Time limit exceeded... Skipping NeuralNetTorch_r79_BAG_L1.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 149.92s of the 49.53s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=16, gpus=0, mem=0.0/2.9 GB
# 	Ensemble Weights: {'LightGBMXT_BAG_L1': 1.0}
# 	0.9727	 = Validation score   (f1)
# 	0.63s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 48.86s of the 48.83s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	0.9727	 = Validation score   (f1)
# 	16.1s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 32.62s of the 32.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	0.9636	 = Validation score   (f1)
# 	16.32s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 16.18s of the 16.15s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/3.0 GB
# 	0.9596	 = Validation score   (f1)
# 	0.67s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 15.34s of the 15.32s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/3.0 GB
# 	0.9596	 = Validation score   (f1)
# 	0.63s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 14.55s of the 14.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	Ran out of time, early stopping on iteration 459.
# 	Ran out of time, early stopping on iteration 476.
# 	Ran out of time, early stopping on iteration 645.
# 	Ran out of time, early stopping on iteration 658.
# 	0.9683	 = Validation score   (f1)
# 	11.99s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 2.47s of the 2.44s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/2.9 GB
# 	0.9596	 = Validation score   (f1)
# 	0.68s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 1.63s of the 1.60s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/3.0 GB
# 	0.9596	 = Validation score   (f1)
# 	0.67s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 149.92s of the 0.57s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=16, gpus=0, mem=0.0/2.9 GB
# 	Ensemble Weights: {'LightGBMXT_BAG_L1': 1.0}
# 	0.9727	 = Validation score   (f1)
# 	0.66s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 150.12s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 60891.0 rows/s (432 batch size)
# Enabling decision threshold calibration (calibrate_decision_threshold='auto', metric is valid, problem_type is 'binary')
# Calibrating decision threshold to optimize metric f1 | Checking 51 thresholds...
# Calibrating decision threshold via fine-grained search | Checking 38 thresholds...
# 	Base Threshold: 0.500	| val: 0.9727
# 	Best Threshold: 0.500	| val: 0.9727
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("C:\Users\Sc\Documents\GitHub\challenge-machine-learning\autogluon_models\ds_sub_fit\sub_fit_ho")
# Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0     ExtraTreesGini_BAG_L1       1.000000   0.960352          f1        0.378937       0.124501   0.664552                 0.378937                0.124501           0.664552            1       True          6
# 1   RandomForestGini_BAG_L1       1.000000   0.955357          f1        0.393146       0.117313   1.078167                 0.393146                0.117313           1.078167            1       True          3
# 2      CatBoost_r177_BAG_L1       1.000000   0.955357          f1        0.402746       0.012168   2.810553                 0.402746                0.012168           2.810553            1       True         10
# 3           CatBoost_BAG_L1       1.000000   0.960000          f1        0.437484       0.013845  18.526298                 0.437484                0.013845          18.526298            1       True          5
# 4            XGBoost_BAG_L1       1.000000   0.968326          f1        3.354094       0.021242   9.696035                 3.354094                0.021242           9.696035            1       True          8
# 5   RandomForestEntr_BAG_L1       0.962963   0.963964          f1        0.380680       0.116796   0.628742                 0.380680                0.116796           0.628742            1       True          4
# 6     ExtraTreesEntr_BAG_L1       0.962963   0.960000          f1        0.384383       0.121900   0.661589                 0.384383                0.121900           0.661589            1       True          7
# 7           LightGBM_BAG_L1       0.962963   0.968610          f1        0.448707       0.007782  17.043819                 0.448707                0.007782          17.043819            1       True          2
# 8      LightGBMLarge_BAG_L1       0.962963   0.958904          f1        0.459224       0.008706  20.717266                 0.459224                0.008706          20.717266            1       True          9
# 9   RandomForestGini_BAG_L2       0.962963   0.959641          f1        7.150207       0.662372  68.431078                 0.355040                0.120037           0.673720            2       True         14
# 10    ExtraTreesEntr_BAG_L2       0.962963   0.959641          f1        7.155344       0.666806  68.422438                 0.360177                0.124470           0.665080            2       True         18
# 11  RandomForestEntr_BAG_L2       0.962963   0.959641          f1        7.167629       0.663683  68.384498                 0.372462                0.121348           0.627141            2       True         15
# 12    ExtraTreesGini_BAG_L2       0.962963   0.959641          f1        7.168135       0.665084  68.436998                 0.372968                0.122749           0.679640            2       True         17
# 13        LightGBMXT_BAG_L2       0.962963   0.972727          f1        7.195416       0.555838  83.857768                 0.400249                0.013503          16.100410            2       True         12
# 14          CatBoost_BAG_L2       0.962963   0.968326          f1        7.210905       0.563642  79.747699                 0.415738                0.021306          11.990342            2       True         16
# 15          LightGBM_BAG_L2       0.962963   0.963636          f1        7.231513       0.553663  84.081115                 0.436346                0.011328          16.323757            2       True         13
# 16        LightGBMXT_BAG_L1       0.923077   0.972727          f1        0.614989       0.006788  16.647604                 0.614989                0.006788          16.647604            1       True          1
# 17      WeightedEnsemble_L2       0.923077   0.972727          f1        0.630578       0.009239  17.281605                 0.015589                0.002451           0.634002            2       True         11
# 18      WeightedEnsemble_L3       0.923077   0.972727          f1        0.632991       0.009396  17.309239                 0.018002                0.002608           0.661636            3       True         19
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	162s	 = DyStack   runtime |	438s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 438s
# AutoGluon will save models to "C:\Users\Sc\Documents\GitHub\challenge-machine-learning\autogluon_models"
# Train Data Rows:    3883
# Train Data Columns: 18
# Label Column:       ASZ [Sch]
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    3140.15 MB
# 	Train Data (Original)  Memory Usage: 0.53 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 1): ['APHu [bar]']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 17 | ['ZUs [s]', 'ZSx [s]', 'ACPx [cm³]', 'ZDx [s]', 'ZEx [s]', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 17 | ['ZUs [s]', 'ZSx [s]', 'ACPx [cm³]', 'ZDx [s]', 'ZEx [s]', ...]
# 	0.0s = Fit runtime
# 	17 features in original data used to generate 17 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.50 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.05s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'f1'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 108 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 292.20s of the 438.40s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	0.9721	 = Validation score   (f1)
# 	17.16s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 274.89s of the 421.09s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	0.968	 = Validation score   (f1)
# 	15.73s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 259.02s of the 405.22s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/2.9 GB
# 	0.9565	 = Validation score   (f1)
# 	0.67s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 258.19s of the 404.39s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/3.1 GB
# 	0.952	 = Validation score   (f1)
# 	0.65s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 257.38s of the 403.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	0.9528	 = Validation score   (f1)
# 	14.96s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 242.32s of the 388.52s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/2.9 GB
# 	0.9531	 = Validation score   (f1)
# 	0.68s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 241.46s of the 387.66s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/3.1 GB
# 	0.9685	 = Validation score   (f1)
# 	0.67s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 240.62s of the 386.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# No improvement since epoch 2: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 2: early stopping
# 	0.9799	 = Validation score   (f1)
# 	22.78s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 217.58s of the 363.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	0.9641	 = Validation score   (f1)
# 	18.12s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 199.32s of the 345.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	0.9597	 = Validation score   (f1)
# 	42.64s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 156.46s of the 302.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	0.9597	 = Validation score   (f1)
# 	23.8s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 132.38s of the 278.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	0.9528	 = Validation score   (f1)
# 	11.8s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 120.46s of the 266.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	0.9603	 = Validation score   (f1)
# 	63.17s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 57.07s of the 203.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	0.9672	 = Validation score   (f1)
# 	24.51s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 32.36s of the 178.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	Ran out of time, stopping training early. (Stopping on epoch 13)
# 	Ran out of time, stopping training early. (Stopping on epoch 14)
# 	Ran out of time, stopping training early. (Stopping on epoch 14)
# 	Ran out of time, stopping training early. (Stopping on epoch 13)
# 	Ran out of time, stopping training early. (Stopping on epoch 15)
# 	Ran out of time, stopping training early. (Stopping on epoch 16)
# 	Ran out of time, stopping training early. (Stopping on epoch 18)
# 	Ran out of time, stopping training early. (Stopping on epoch 22)
# 	0.9725	 = Validation score   (f1)
# 	30.71s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 1.37s of the 147.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	Ran out of time, early stopping on iteration 12.
# 	Ran out of time, early stopping on iteration 15.
# 	Ran out of time, early stopping on iteration 14.
# 	Ran out of time, early stopping on iteration 17.
# 	Ran out of time, early stopping on iteration 18.
# 	Ran out of time, early stopping on iteration 20.
# 	Ran out of time, early stopping on iteration 22.
# 	Ran out of time, early stopping on iteration 28.
# 	0.9569	 = Validation score   (f1)
# 	1.25s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 0.01s of the 146.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	Warning: Model has no time left to train, skipping model... (Time Left = -0.0s)
# 	Time limit exceeded... Skipping LightGBM_r96_BAG_L1.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 145.56s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=16, gpus=0, mem=0.0/3.2 GB
# 	Ensemble Weights: {'LightGBMXT_BAG_L1': 0.385, 'RandomForestEntr_BAG_L1': 0.231, 'NeuralNetFastAI_BAG_L1': 0.231, 'XGBoost_BAG_L1': 0.077, 'NeuralNetTorch_BAG_L1': 0.077}
# 	0.984	 = Validation score   (f1)
# 	0.87s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 144.65s of the 144.61s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	0.968	 = Validation score   (f1)
# 	13.6s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 130.92s of the 130.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	0.9721	 = Validation score   (f1)
# 	14.46s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 116.33s of the 116.29s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/3.7 GB
# 	0.9721	 = Validation score   (f1)
# 	0.84s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 115.25s of the 115.22s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/3.7 GB
# 	0.9641	 = Validation score   (f1)
# 	0.78s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 114.27s of the 114.23s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	0.9683	 = Validation score   (f1)
# 	18.72s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 95.42s of the 95.38s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/3.6 GB
# 	0.9721	 = Validation score   (f1)
# 	0.71s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 94.54s of the 94.50s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=16, gpus=0, mem=0.0/3.6 GB
# 	0.968	 = Validation score   (f1)
# 	0.75s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 93.60s of the 93.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# No improvement since epoch 3: early stopping
# No improvement since epoch 9: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 1: early stopping
# No improvement since epoch 3: early stopping
# 	0.9841	 = Validation score   (f1)
# 	23.99s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 69.30s of the 69.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	0.9721	 = Validation score   (f1)
# 	16.24s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 52.90s of the 52.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sc\PycharmProjects\JupyterProject\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	0.9685	 = Validation score   (f1)
# 	29.74s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 22.91s of the 22.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	0.9719	 = Validation score   (f1)
# 	15.25s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 7.50s of the 7.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=8, gpus=0)
# 	Ran out of time, early stopping on iteration 227.
# 	Ran out of time, early stopping on iteration 234.
# 	Ran out of time, early stopping on iteration 251.
# 	Ran out of time, early stopping on iteration 257.
# 	Ran out of time, early stopping on iteration 272.
# 	Ran out of time, early stopping on iteration 283.
# 	Ran out of time, early stopping on iteration 301.
# 	Ran out of time, early stopping on iteration 338.
# 	0.968	 = Validation score   (f1)
# 	7.1s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the -0.07s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=16, gpus=0, mem=0.0/3.7 GB
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L2': 1.0}
# 	0.9841	 = Validation score   (f1)
# 	0.98s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 439.55s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 944.6 rows/s (486 batch size)
# Enabling decision threshold calibration (calibrate_decision_threshold='auto', metric is valid, problem_type is 'binary')
# Calibrating decision threshold to optimize metric f1 | Checking 51 thresholds...
# Calibrating decision threshold via fine-grained search | Checking 38 thresholds...
# 	Base Threshold: 0.500	| val: 0.9841
# 	Best Threshold: 0.500	| val: 0.9841
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("C:\Users\Sc\Documents\GitHub\challenge-machine-learning\autogluon_models")
# Model leaderboard
#                           model  score_test  score_val eval_metric  \
# 0        NeuralNetFastAI_BAG_L2    0.987013   0.984127          f1
# 1           WeightedEnsemble_L3    0.987013   0.984127          f1
# 2          CatBoost_r177_BAG_L1    0.986667   0.952756          f1
# 3               CatBoost_BAG_L1    0.986667   0.952756          f1
# 4           WeightedEnsemble_L2    0.986667   0.984000          f1
# 5            CatBoost_r9_BAG_L1    0.974359   0.956863          f1
# 6         ExtraTreesGini_BAG_L1    0.974359   0.953125          f1
# 7         ExtraTreesEntr_BAG_L2    0.973684   0.968000          f1
# 8         ExtraTreesGini_BAG_L2    0.973684   0.972112          f1
# 9       RandomForestEntr_BAG_L2    0.973684   0.964143          f1
# 10      RandomForestEntr_BAG_L1    0.972973   0.952000          f1
# 11            LightGBMXT_BAG_L1    0.972973   0.972112          f1
# 12        ExtraTreesEntr_BAG_L1    0.961039   0.968504          f1
# 13      RandomForestGini_BAG_L1    0.961039   0.956522          f1
# 14      RandomForestGini_BAG_L2    0.961039   0.972112          f1
# 15        NeuralNetTorch_BAG_L2    0.961039   0.968504          f1
# 16         CatBoost_r177_BAG_L2    0.960000   0.968000          f1
# 17         LightGBMLarge_BAG_L1    0.958904   0.959677          f1
# 18       NeuralNetFastAI_BAG_L1    0.950000   0.979920          f1
# 19  NeuralNetFastAI_r191_BAG_L1    0.950000   0.972549          f1
# 20              LightGBM_BAG_L1    0.948718   0.968000          f1
# 21              CatBoost_BAG_L2    0.945946   0.968254          f1
# 22              LightGBM_BAG_L2    0.944444   0.972112          f1
# 23               XGBoost_BAG_L1    0.933333   0.964143          f1
# 24    NeuralNetTorch_r79_BAG_L1    0.929577   0.960317          f1
# 25            LightGBMXT_BAG_L2    0.929577   0.968000          f1
# 26               XGBoost_BAG_L2    0.929577   0.972112          f1
# 27         LightGBM_r131_BAG_L1    0.914286   0.967213          f1
# 28        NeuralNetTorch_BAG_L1    0.901408   0.959677          f1
# 29         LightGBMLarge_BAG_L2    0.882353   0.971888          f1
#
#     pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 0      1643.849529       0.945880  253.160611                 0.453282
# 1      1643.851712       0.948470  254.139005                 0.002184
# 2         0.151268       0.016587   11.801816                 0.151268
# 3         0.453499       0.013544   14.955575                 0.453499
# 4      1627.793444       0.302384  102.215258                 0.004193
# 5         0.022259       0.016669    1.254099                 0.022259
# 6         0.440140       0.131632    0.681098                 0.440140
# 7      1643.469958       1.004040  229.927881                 0.073711
# 8      1643.470078       1.008326  229.888774                 0.073830
# 9      1643.488946       1.016359  229.955578                 0.092699
# 10        0.455725       0.118286    0.646614                 0.455725
# 11        0.812223       0.007482   17.155235                 0.812223
# 12        0.397901       0.125023    0.668967                 0.397901
# 13        0.512659       0.118519    0.666179                 0.512659
# 14     1643.618471       1.058838  230.018194                 0.222224
# 15     1643.644482       1.010075  258.917322                 0.248235
# 16     1643.428653       0.899757  236.275977                 0.032405
# 17        0.237092       0.013930   23.797366                 0.237092
# 18        4.174177       0.069634   22.779094                 4.174177
# 19       12.531929       0.079663   30.706940                12.531929
# 20        0.566862       0.006766   15.728148                 0.566862
# 21     1643.429466       0.900298  247.897933                 0.033219
# 22     1643.491938       0.885307  243.634043                 0.095690
# 23     1612.008109       0.021497   18.124916              1612.008109
# 24        0.681749       0.083480   63.169988                 0.681749
# 25     1643.416948       0.885130  242.774138                 0.020701
# 26     1643.494221       0.902255  245.411012                 0.097974
# 27        0.193713       0.013592   24.506982                 0.193713
# 28       10.339016       0.082174   42.637349                10.339016
# 29     1643.419541       0.885410  244.426705                 0.023293
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.071512          23.986409            2       True
# 1                 0.002590           0.978393            3       True
# 2                 0.016587          11.801816            1       True
# 3                 0.013544          14.955575            1       True
# 4                 0.003311           0.872051            2       True
# 5                 0.016669           1.254099            1       True
# 6                 0.131632           0.681098            1       True
# 7                 0.129672           0.753679            2       True
# 8                 0.133958           0.714571            2       True
# 9                 0.141991           0.781375            2       True
# 10                0.118286           0.646614            1       True
# 11                0.007482          17.155235            1       True
# 12                0.125023           0.668967            1       True
# 13                0.118519           0.666179            1       True
# 14                0.184470           0.843992            2       True
# 15                0.135707          29.743119            2       True
# 16                0.025388           7.101774            2       True
# 17                0.013930          23.797366            1       True
# 18                0.069634          22.779094            1       True
# 19                0.079663          30.706940            1       True
# 20                0.006766          15.728148            1       True
# 21                0.025929          18.723731            2       True
# 22                0.010938          14.459841            2       True
# 23                0.021497          18.124916            1       True
# 24                0.083480          63.169988            1       True
# 25                0.010762          13.599936            2       True
# 26                0.027887          16.236810            2       True
# 27                0.013592          24.506982            1       True
# 28                0.082174          42.637349            1       True
# 29                0.011041          15.252502            2       True
#
#     fit_order
# 0          25
# 1          30
# 2          12
# 3           5
# 4          17
# 5          16
# 6           6
# 7          24
# 8          23
# 9          21
# 10          4
# 11          1
# 12          7
# 13          3
# 14         20
# 15         27
# 16         29
# 17         11
# 18          8
# 19         15
# 20          2
# 21         22
# 22         19
# 23          9
# 24         13
# 25         18
# 26         26
# 27         14
# 28         10
# 29         28

# %% [markdown]
# #### Evaluation ####

# %%
y_pred = predictor.predict(test_df)
y_pred_proba = predictor.predict_proba(test_df)


print("Classification report")
print(classification_report(test_df['ASZ [Sch]'], y_pred))
# Out:
# Classification report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       933
#            1       0.97      1.00      0.99        38
#
#     accuracy                           1.00       971
#    macro avg       0.99      1.00      0.99       971
# weighted avg       1.00      1.00      1.00       971

# %% [markdown]
# #### Confusion Matrix ####

# %%
cm = confusion_matrix(test_df['ASZ [Sch]'], y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('AutoGluon - Confusion Matrix')
plt.show()

# %% [markdown]
# #### Feature importance ####

# %%
importance = predictor.feature_importance(test_df)
print("\n=== Feature Importance ===")
print(importance)

plt.figure(figsize=(10, 6))
importance.plot(kind='barh')
plt.xlabel('Importance Score')
plt.title('Feature Importance - AutoGluon')
plt.tight_layout()
plt.show()
# Out:
# These features in provided data are not utilized by the predictor and will be ignored: ['APHu [bar]']
# Computing feature importance via permutation shuffling for 17 features using 971 rows with 5 shuffle sets...
# 	114.77s	= Expected runtime (22.95s per shuffle set)
